# %%
import pandas as pd

# Define the classes and their descriptions
data = {
    'class': [
        'Apple_Scab_Leaf', 'Apple_Scab_Leaf', 'Apple_Scab_Leaf',
        'Apple_leaf', 'Apple_leaf', 'Apple_leaf',
        'Apple_rust_leaf', 'Apple_rust_leaf', 'Apple_rust_leaf',
        'Bell_pepper_leaf', 'Bell_pepper_leaf', 'Bell_pepper_leaf',
        'Bell_pepper_leaf_spot', 'Bell_pepper_leaf_spot', 'Bell_pepper_leaf_spot',
        'Blueberry_leaf', 'Blueberry_leaf', 'Blueberry_leaf',
        'Cherry_leaf', 'Cherry_leaf', 'Cherry_leaf',
        'Corn_Gray_leaf_spot', 'Corn_Gray_leaf_spot', 'Corn_Gray_leaf_spot',
        'Corn_leaf_blight', 'Corn_leaf_blight', 'Corn_leaf_blight',
        'Corn_rust_leaf', 'Corn_rust_leaf', 'Corn_rust_leaf',
        'Peach_leaf', 'Peach_leaf', 'Peach_leaf',
        'Potato_leaf_early_blight', 'Potato_leaf_early_blight', 'Potato_leaf_early_blight',
        'Potato_leaf_late_blight', 'Potato_leaf_late_blight', 'Potato_leaf_late_blight',
        'Raspberry_leaf', 'Raspberry_leaf', 'Raspberry_leaf',
        'Soyabean_leaf', 'Soyabean_leaf', 'Soyabean_leaf',
        'Squash_Powdery_mildew_leaf', 'Squash_Powdery_mildew_leaf', 'Squash_Powdery_mildew_leaf',
        'Strawberry_leaf', 'Strawberry_leaf', 'Strawberry_leaf',
        'Tomato_Early_blight_leaf', 'Tomato_Early_blight_leaf', 'Tomato_Early_blight_leaf',
        'Tomato_Septoria_leaf_spot', 'Tomato_Septoria_leaf_spot', 'Tomato_Septoria_leaf_spot',
        'Tomato_leaf', 'Tomato_leaf', 'Tomato_leaf',
        'Tomato_leaf_bacterial_spot', 'Tomato_leaf_bacterial_spot', 'Tomato_leaf_bacterial_spot',
        'Tomato_leaf_late_blight', 'Tomato_leaf_late_blight', 'Tomato_leaf_late_blight',
        'Tomato_leaf_mosaic_virus', 'Tomato_leaf_mosaic_virus', 'Tomato_leaf_mosaic_virus',
        'Tomato_leaf_yellow_virus', 'Tomato_leaf_yellow_virus', 'Tomato_leaf_yellow_virus',
        'Tomato_mold_leaf', 'Tomato_mold_leaf', 'Tomato_mold_leaf',
        'Tomato_two_spotted_spider_mites_leaf', 'Tomato_two_spotted_spider_mites_leaf', 'Tomato_two_spotted_spider_mites_leaf',
        'grape_leaf', 'grape_leaf', 'grape_leaf',
        'grape_leaf_black_rot', 'grape_leaf_black_rot', 'grape_leaf_black_rot'
    ],
    'description': [
        'Apple Scab affects the leaves, causing dark, sunken lesions with a characteristic olive-brown color.',
        'Apple Scab is a common disease on apple trees, characterized by dark, sunken spots on the leaves.',
        'Leaves infected with Apple Scab develop olive-brown lesions, leading to reduced photosynthesis.',
        
        'Apple leaf spots are usually dark and sunken, causing premature leaf drop.',
        'Leaves of apple trees with this disease show dark spots and may curl or drop.',
        'Apple leaf infections cause dark lesions that may lead to leaf drop and reduced yield.',
        
        'Apple rust on leaves causes orange pustules and can severely affect plant health.',
        'Leaves with Apple rust exhibit small, orange pustules on the upper surfaces.',
        'Apple rust leads to orange-brown lesions on the leaves and can reduce fruit quality.',
        
        'Bell pepper leaves can develop yellow spots and eventually become necrotic.',
        'Leaves of bell peppers with this disease may show spots and yellowing.',
        'Bell pepper leaf infections often result in leaf drop and reduced fruit production.',
        
        'Bell pepper leaf spot is characterized by dark, sunken lesions with a yellow halo.',
        'Leaves with Bell pepper leaf spot show small, dark lesions that enlarge over time.',
        'Bell pepper leaves with spots can lead to reduced plant vigor and yield loss.',
        
        'Blueberry leaves affected by disease may show dark, irregular spots and premature leaf drop.',
        'Leaves of blueberry plants with disease often exhibit dark, necrotic areas.',
        'Blueberry leaf infections result in dark spots and can affect overall plant health.',
        
        'Cherry leaves may show red or purple spots, eventually leading to leaf drop.',
        'Cherry leaf infections cause red or purple lesions that may coalesce into larger areas.',
        'Leaves of cherry trees with disease show discoloration and necrosis, impacting fruit quality.',
        
        'Corn gray leaf spot causes elongated, grayish-brown lesions on the leaves.',
        'Leaves affected by Corn gray leaf spot exhibit grayish-brown lesions with yellow halos.',
        'Gray leaf spot on corn leads to reduced photosynthesis and lower yield.',
        
        'Corn leaf blight shows large, brown lesions on the leaves with a dark border.',
        'Corn leaves affected by blight develop large, dark lesions that can coalesce.',
        'Corn leaf blight reduces photosynthesis and plant vigor, leading to yield loss.',
        
        'Corn rust leads to the formation of pustules on the leaf surface, causing reduced plant health.',
        'Leaves with Corn rust develop small, orange pustules that burst open and release spores.',
        'Corn rust affects photosynthesis and can severely impact yield and plant health.',
        
        'Peach leaves with disease show dark spots and may curl or drop prematurely.',
        'Leaves of peach trees affected by disease develop dark, sunken spots and may fall off.',
        'Peach leaf infections cause dark lesions and can lead to reduced fruit quality and yield.',
        
        'Potato early blight causes dark, sunken lesions on leaves, which may lead to early leaf drop.',
        'Leaves with Potato early blight show concentric rings and may turn yellow and drop off.',
        'Early blight on potato leaves causes dark, circular lesions with concentric rings.',
        
        'Potato late blight causes large, irregularly shaped lesions on leaves and stems.',
        'Leaves affected by Potato late blight develop large, dark lesions with a grayish mold.',
        'Late blight on potato leads to rapid leaf and stem decay and can reduce yield significantly.',
        
        'Raspberry leaf disease causes yellowing and curling of leaves, which may drop prematurely.',
        'Leaves with Raspberry leaf disease exhibit yellow spots and may curl or shrivel.',
        'Raspberry leaf infections result in reduced photosynthesis and can impact fruit quality.',
        
        'Soybean leaf spots show dark, necrotic areas that may coalesce and lead to premature leaf drop.',
        'Leaves of soybean plants affected by disease show dark spots and may turn yellow.',
        'Soybean leaf infections lead to dark lesions and can affect overall plant health and yield.',
        
        'Squash powdery mildew causes white, powdery spots on leaves that can spread quickly.',
        'Leaves affected by Squash powdery mildew develop a white, powdery substance on the surface.',
        'Powdery mildew on squash leaves reduces photosynthesis and can lead to lower fruit yield.',
        
        'Strawberry leaf disease causes red or brown spots on leaves, leading to reduced fruit quality.',
        'Leaves with Strawberry leaf disease exhibit dark, necrotic areas and may drop prematurely.',
        'Strawberry leaf infections result in reduced plant vigor and fruit quality.',
        
        'Tomato early blight causes dark, sunken lesions with concentric rings on the leaves.',
        'Leaves affected by Tomato early blight show dark spots with concentric rings and yellow halos.',
        'Early blight on tomato leaves leads to reduced photosynthesis and plant vigor.',
        
        'Tomato septoria leaf spot causes small, dark lesions with gray centers on the leaves.',
        'Leaves with Tomato septoria leaf spot exhibit small, dark lesions with a grayish center.',
        'Septoria leaf spot on tomatoes reduces plant health and fruit quality.',
        
        'Tomato leaf disease causes various lesions and discolorations, affecting overall plant health.',
        'Leaves of tomato plants affected by disease show dark spots and may curl or drop.',
        'Tomato leaf infections result in reduced photosynthesis and plant vigor.',
        
        'Tomato leaf bacterial spot shows dark, water-soaked lesions with a yellow halo on leaves.',
        'Leaves affected by Tomato leaf bacterial spot develop dark, water-soaked lesions with a yellow border.',
        'Bacterial spot on tomato leaves leads to reduced plant health and fruit quality.',
        
        'Tomato leaf late blight causes large, dark lesions with a grayish mold on the leaves.',
        'Leaves with Tomato leaf late blight exhibit large, dark lesions and a grayish, fuzzy mold.',
        'Late blight on tomato leaves can cause rapid plant decay and reduce yield.',
        
        'Tomato leaf mosaic virus causes yellowing and mottling of leaves, affecting plant growth.',
        'Leaves affected by Tomato leaf mosaic virus show yellowing and mosaic-like patterns.',
        'Mosaic virus on tomato leaves results in reduced photosynthesis and plant health.',
        
        'Tomato leaf yellow virus leads to yellowing of leaves and reduced plant growth.',
        'Leaves with Tomato leaf yellow virus exhibit yellowing and stunted growth.',
        'Yellow virus on tomato leaves affects overall plant health and fruit yield.',
        
        'Tomato mold on leaves appears as a white, powdery substance that can spread rapidly.',
        'Leaves affected by Tomato mold show white, powdery spots and may drop prematurely.',
        'Mold on tomato leaves reduces photosynthesis and can lead to lower fruit yield.',
        
        'Tomato two-spotted spider mites cause stippling and yellowing of leaves.',
        'Leaves with Tomato two-spotted spider mites show small, yellowish stipples and may curl.',
        'Spider mites on tomato leaves reduce photosynthesis and plant health.',
        
        'Grape leaves affected by disease may show dark, sunken lesions and premature leaf drop.',
        'Leaves with grape leaf disease develop dark spots and may curl or drop early.',
        'Grape leaf infections result in reduced photosynthesis and can affect fruit quality.',
        
        'Grape leaf black rot causes dark, sunken lesions and a black mold on the leaves.',
        'Leaves with Grape leaf black rot exhibit dark, necrotic areas and a black, fuzzy mold.',
        'Black rot on grape leaves reduces plant health and can impact fruit production.'
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('plant_disease_descriptions.csv', index=False)
